# %%
#km to miles

kilometers = float(input("Enter a distance in kilometers: "))
miles = kilometers / 1.609
print(f"{kilometers} kilometers is {miles} miles")

# %%
#celsius to farenheit

celsius = float(input("Enter a temperature in Celsius: "))
farenheit = (celsius*(9/5)) + 32

print(f"{celsius}°C is {farenheit}°F")

# %%
#binary to decimal, takes input
import math

binary = int(input("Enter a number in binary: "))
decimal = 0
temp1 = binary
power = 0

numDigits = int(math.log10(abs(binary))) + 1

for i in range (numDigits):
  digit = temp1%10
  decimal += digit*(2**power)
  power += 1
  temp1 //= 10

print(f"{binary} in binary is the same as {decimal} in decimal")

# %%
#binary to decimal, does not take input

binary = 101101000
decimal = 0
temp1 = binary
power = 0


for i in range (9):
  digit = temp1%10
  decimal += digit*(2**power)
  power += 1
  temp1 //= 10

print(f"{binary} in binary is the same as {decimal} in decimal")
